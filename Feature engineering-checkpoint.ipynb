# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40669 entries, 4 to 123393
# Data columns (total 59 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    40669 non-null  int64
#  1   fifa_version                 40669 non-null  int64
#  2   long_name                    40669 non-null  object
#  3   player_positions             40669 non-null  object
#  4   overall                      40669 non-null  int64
#  5   potential                    40669 non-null  int64
#  6   age                          40669 non-null  int64
#  7   height_cm                    40669 non-null  int64
#  8   weight_kg                    40669 non-null  int64
#  9   nationality_id               40669 non-null  int64
#  10  nationality_name             40669 non-null  object
#  11  weak_foot                    40669 non-null  int64
#  12  skill_moves                  40669 non-null  int64
#  13  pace                         40669 non-null  float64
#  14  shooting                     40669 non-null  float64
#  15  passing                      40669 non-null  float64
#  16  dribbling                    40669 non-null  float64
#  17  defending                    40669 non-null  float64
#  18  physic                       40669 non-null  float64
#  19  attacking_crossing           40669 non-null  int64
#  20  attacking_finishing          40669 non-null  int64
#  21  attacking_heading_accuracy   40669 non-null  int64
#  22  attacking_short_passing      40669 non-null  int64
#  23  attacking_volleys            40669 non-null  int64
#  24  skill_dribbling              40669 non-null  int64
#  25  skill_curve                  40669 non-null  int64
#  26  skill_fk_accuracy            40669 non-null  int64
#  27  skill_long_passing           40669 non-null  int64
#  28  skill_ball_control           40669 non-null  int64
#  29  movement_acceleration        40669 non-null  int64
#  30  movement_sprint_speed        40669 non-null  int64
#  31  movement_agility             40669 non-null  int64
#  32  movement_reactions           40669 non-null  int64
#  33  movement_balance             40669 non-null  int64
#  34  power_shot_power             40669 non-null  int64
#  35  power_jumping                40669 non-null  int64
#  36  power_stamina                40669 non-null  int64
#  37  power_strength               40669 non-null  int64
#  38  power_long_shots             40669 non-null  int64
#  39  mentality_aggression         40669 non-null  int64
#  40  mentality_interceptions      40669 non-null  int64
#  41  mentality_positioning        40669 non-null  int64
#  42  mentality_vision             40669 non-null  int64
#  43  mentality_penalties          40669 non-null  int64
#  44  mentality_composure          40669 non-null  float64
#  45  defending_marking_awareness  40669 non-null  int64
#  46  defending_standing_tackle    40669 non-null  int64
#  47  defending_sliding_tackle     40669 non-null  int64
#  48  concatenated                 40669 non-null  object
#  49  preferred_foot_Left          40669 non-null  int64
#  50  preferred_foot_Right         40669 non-null  int64
#  51  Attacker                     40669 non-null  int64
#  52  Midfielder                   40669 non-null  int64
#  53  Defender                     40669 non-null  int64
#  54  Keeper                       40669 non-null  int64
#  55  improvement_1_year           40669 non-null  int64
#  56  improvement_2_years          40669 non-null  int64
#  57  improvement_3_years          40669 non-null  int64
#  58  big_potential                40669 non-null  int64
# dtypes: float64(7), int64(48), object(4)
# memory usage: 18.6+ MB
#     player_id  fifa_version                      long_name player_positions  \
# 4          41            17           Andrés Iniesta Luján               CM
# 5          41            18           Andrés Iniesta Luján           CM, LM
# 6          41            19           Andrés Iniesta Luján           CM, LM
# 11         80            17                 Emre Belözoğlu          CM, CDM
# 22        768            17  Felipe Dias da Silva dal Belo               CB
#
#     overall  potential  age  height_cm  weight_kg  nationality_id  \
# 4        88         88   32        171         68              45
# 5        87         87   33        171         68              45
# 6        85         85   34        171         68              45
# 11       77         77   35        170         72              48
# 22       75         75   31        188         75              54
#
#    nationality_name  weak_foot  skill_moves  pace  shooting  passing  \
# 4             Spain          4            4  72.0      70.0     87.0
# 5             Spain          4            4  69.0      70.0     87.0
# 6             Spain          4            4  68.0      70.0     86.0
# 11           Turkey          3            2  53.0      73.0     81.0
# 22           Brazil          3            2  52.0      35.0     51.0
#
#     dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 4        90.0       58.0    59.0                  77                   70
# 5        90.0       58.0    57.0                  77                   70
# 6        88.0       62.0    57.0                  77                   69
# 11       75.0       63.0    67.0                  78                   68
# 22       52.0       79.0    66.0                  34                   20
#
#     attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 4                           54                       92                 74
# 5                           54                       92                 74
# 6                           54                       90                 75
# 11                          43                       83                 69
# 22                          74                       62                 19
#
#     skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 4                90           80                 70                  86
# 5                90           80                 70                  86
# 6                88           80                 70                  84
# 11               75           81                 80                  84
# 22               44           49                 21                  64
#
#     skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 4                   93                     73                     72
# 5                   94                     70                     68
# 6                   91                     70                     66
# 11                  77                     52                     54
# 22                  60                     50                     54
#
#     movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 4                 81                  88                85                65
# 5                 79                  88                84                65
# 6                 79                  84                84                67
# 11                66                  73                84                79
# 22                52                  72                63                68
#
#     power_jumping  power_stamina  power_strength  power_long_shots  \
# 4              54             62              58                71
# 5              47             55              58                71
# 6              47             58              58                70
# 11             72             55              64                77
# 22             70             55              69                40
#
#     mentality_aggression  mentality_interceptions  mentality_positioning  \
# 4                     58                       66                     84
# 5                     58                       66                     84
# 6                     58                       65                     78
# 11                    87                       68                     67
# 22                    70                       81                     29
#
#     mentality_vision  mentality_penalties  mentality_composure  \
# 4                 94                   71                 88.0
# 5                 94                   71                 89.0
# 6                 93                   71                 89.0
# 11                80                   85                 73.0
# 22                46                   35                 67.0
#
#     defending_marking_awareness  defending_standing_tackle  \
# 4                            57                         57
# 5                            57                         57
# 6                            68                         57
# 11                           64                         66
# 22                           80                         80
#
#     defending_sliding_tackle concatenated  preferred_foot_Left  \
# 4                         56        41_17                    0
# 5                         56        41_18                    0
# 6                         56        41_19                    0
# 11                        65        80_17                    1
# 22                        76       768_17                    1
#
#     preferred_foot_Right  Attacker  Midfielder  Defender  Keeper  \
# 4                      1         0           1         0       0
# 5                      1         0           1         0       0
# 6                      1         0           1         0       0
# 11                     0         0           1         0       0
# 22                     0         0           0         1       0
#
#     improvement_1_year  improvement_2_years  improvement_3_years  \
# 4                  -27                  -35                  -69
# 5                   -8                  -42                  -99
# 6                  -34                  -91                 -171
# 11                  30                    0                  -25
# 22                 -31                  -56                 -109
#
#     big_potential
# 4               0
# 5               0
# 6               0
# 11              0
# 22              0

# %%
pd.set_option('display.max_columns', None)
df = df[df['improvement_3_years'] != 0]
df.info()
df.head()

# %%
att_df = df[df['Attacker'] == 1]
mid_df = df[df['Midfielder'] == 1]
def_df = df[df['Defender'] == 1]
nokeeper_df = df[df['Keeper'] == 0]

# %%
file_path = 'Attackers.csv'
att_df.to_csv(file_path, index=False)

print(f'DataFrame att_df has been saved as {file_path}')

file_path1 = 'Midfielders.csv'
mid_df.to_csv(file_path1, index=False)

print(f'DataFrame mid_df has been saved as {file_path1}')

file_path2 = 'Defenders.csv'
def_df.to_csv(file_path2, index=False)

print(f'DataFrame def_df has been saved as {file_path2}')

file_path3 = 'NoKeepers.csv'
nokeeper_df.to_csv(file_path3, index=False)

print(f'DataFrame nokeeper_df has been saved as {file_path3}')
# Out:
# DataFrame att_df has been saved as Attackers.csv
# DataFrame mid_df has been saved as Midfielders.csv
# DataFrame def_df has been saved as Defenders.csv
# DataFrame nokeeper_df has been saved as NoKeepers.csv

# %%
# Hierna komt code die wss pas bij RF gedaan moet worden

# %%
independent_variables = ['age', 'height_cm', 'weight_kg', 'weak_foot', 'skill_moves', 'pace', 'shooting',
       'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'preferred_foot_Left', 'preferred_foot_Right', 'Attacker', 'Midfielder',
       'Defender', 'Keeper']

target_variable = "big_potential"
X = df[independent_variables]
y = df[target_variable]

clf = RandomForestClassifier()
clf.fit(X, y)

feature_importance = clf.feature_importances_

threshold = 0.025 

feature_importance_df = pd.DataFrame({'Feature': independent_variables, 'Importance': feature_importance})

selected_features = feature_importance_df[feature_importance_df['Importance'] > threshold]

print(selected_features)
# Out:
#                        Feature  Importance
# 0                          age    0.064846
# 1                    height_cm    0.025234
# 11          attacking_crossing    0.026490
# 13  attacking_heading_accuracy    0.025594
# 14     attacking_short_passing    0.026363
# 15           attacking_volleys    0.025078
# 16             skill_dribbling    0.028377
# 17                 skill_curve    0.025956
# 18           skill_fk_accuracy    0.025682
# 19          skill_long_passing    0.025246
# 20          skill_ball_control    0.027268
# 25            movement_balance    0.025409
# 27               power_jumping    0.025255
# 31        mentality_aggression    0.025065
# 34            mentality_vision    0.025542
# 35         mentality_penalties    0.027441
# 36         mentality_composure    0.027546

# %%
selected_features_with_target = df[selected_features['Feature'].values].copy()
selected_features_with_target[target_variable] = df[target_variable]

correlation_with_target = selected_features_with_target.corr()[target_variable].drop(target_variable)

sorted_features = correlation_with_target.abs().sort_values(ascending=False).index

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation_with_target[sorted_features].index, y=correlation_with_target[sorted_features].values, palette="coolwarm_r")  # "_r" reverses the color order

plt.xlabel("Selected Features")
plt.ylabel("Correlation with Target Variable")
plt.title("Correlation between Selected Features and Target Variable")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
file_path = 'featureengineereddata.csv'
df_selected.to_csv(file_path, index=False)

print(f'DataFrame df_selected has been saved as {file_path}')
# Out:
# DataFrame df_selected has been saved as featureengineereddata.csv
