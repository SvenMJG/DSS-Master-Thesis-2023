# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
    cohen_kappa_score,
    balanced_accuracy_score,
)
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
import numpy as np

# %%
df.head()
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11193 entries, 0 to 11192
# Data columns (total 59 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    11193 non-null  int64
#  1   fifa_version                 11193 non-null  int64
#  2   long_name                    11193 non-null  object
#  3   player_positions             11193 non-null  object
#  4   overall                      11193 non-null  int64
#  5   potential                    11193 non-null  int64
#  6   age                          11193 non-null  int64
#  7   height_cm                    11193 non-null  int64
#  8   weight_kg                    11193 non-null  int64
#  9   nationality_id               11193 non-null  int64
#  10  nationality_name             11193 non-null  object
#  11  weak_foot                    11193 non-null  int64
#  12  skill_moves                  11193 non-null  int64
#  13  pace                         11193 non-null  float64
#  14  shooting                     11193 non-null  float64
#  15  passing                      11193 non-null  float64
#  16  dribbling                    11193 non-null  float64
#  17  defending                    11193 non-null  float64
#  18  physic                       11193 non-null  float64
#  19  attacking_crossing           11193 non-null  int64
#  20  attacking_finishing          11193 non-null  int64
#  21  attacking_heading_accuracy   11193 non-null  int64
#  22  attacking_short_passing      11193 non-null  int64
#  23  attacking_volleys            11193 non-null  int64
#  24  skill_dribbling              11193 non-null  int64
#  25  skill_curve                  11193 non-null  int64
#  26  skill_fk_accuracy            11193 non-null  int64
#  27  skill_long_passing           11193 non-null  int64
#  28  skill_ball_control           11193 non-null  int64
#  29  movement_acceleration        11193 non-null  int64
#  30  movement_sprint_speed        11193 non-null  int64
#  31  movement_agility             11193 non-null  int64
#  32  movement_reactions           11193 non-null  int64
#  33  movement_balance             11193 non-null  int64
#  34  power_shot_power             11193 non-null  int64
#  35  power_jumping                11193 non-null  int64
#  36  power_stamina                11193 non-null  int64
#  37  power_strength               11193 non-null  int64
#  38  power_long_shots             11193 non-null  int64
#  39  mentality_aggression         11193 non-null  int64
#  40  mentality_interceptions      11193 non-null  int64
#  41  mentality_positioning        11193 non-null  int64
#  42  mentality_vision             11193 non-null  int64
#  43  mentality_penalties          11193 non-null  int64
#  44  mentality_composure          11193 non-null  float64
#  45  defending_marking_awareness  11193 non-null  int64
#  46  defending_standing_tackle    11193 non-null  int64
#  47  defending_sliding_tackle     11193 non-null  int64
#  48  concatenated                 11193 non-null  object
#  49  preferred_foot_Left          11193 non-null  int64
#  50  preferred_foot_Right         11193 non-null  int64
#  51  Attacker                     11193 non-null  int64
#  52  Midfielder                   11193 non-null  int64
#  53  Defender                     11193 non-null  int64
#  54  Keeper                       11193 non-null  int64
#  55  improvement_1_year           11193 non-null  int64
#  56  improvement_2_years          11193 non-null  int64
#  57  improvement_3_years          11193 non-null  int64
#  58  big_potential                11193 non-null  int64
# dtypes: float64(7), int64(48), object(4)
# memory usage: 5.0+ MB
# Index(['player_id', 'fifa_version', 'long_name', 'player_positions', 'overall',
#        'potential', 'age', 'height_cm', 'weight_kg', 'nationality_id',
#        'nationality_name', 'weak_foot', 'skill_moves', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle', 'concatenated',
#        'preferred_foot_Left', 'preferred_foot_Right', 'Attacker', 'Midfielder',
#        'Defender', 'Keeper', 'improvement_1_year', 'improvement_2_years',
#        'improvement_3_years', 'big_potential'],
#       dtype='object')

# %%
independent_variables = ['age', 'height_cm', 'weight_kg', 'weak_foot', 'skill_moves', 'pace', 'shooting',
       'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'preferred_foot_Left', 'preferred_foot_Right', 'Attacker', 'Midfielder',
       'Defender', 'Keeper']

target_variable = "big_potential"
X = df[independent_variables]
y = df[target_variable]

clf = RandomForestClassifier()
clf.fit(X, y)

feature_importance = clf.feature_importances_

threshold = 0.025 

feature_importance_df = pd.DataFrame({'Feature': independent_variables, 'Importance': feature_importance})

selected_features = feature_importance_df[feature_importance_df['Importance'] > threshold]

print(selected_features)
print(selected_features['Feature'].tolist())
# Out:
#                     Feature  Importance
# 0                       age    0.067421
# 1                 height_cm    0.028606
# 8                 dribbling    0.025002
# 11       attacking_crossing    0.026125
# 16          skill_dribbling    0.030556
# 17              skill_curve    0.028562
# 18        skill_fk_accuracy    0.027424
# 20       skill_ball_control    0.030045
# 25         movement_balance    0.025393
# 29           power_strength    0.025766
# 31     mentality_aggression    0.026964
# 32  mentality_interceptions    0.026212
# 34         mentality_vision    0.025499
# 35      mentality_penalties    0.029925
# 36      mentality_composure    0.026005
# ['age', 'height_cm', 'dribbling', 'attacking_crossing', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_ball_control', 'movement_balance', 'power_strength', 'mentality_aggression', 'mentality_interceptions', 'mentality_vision', 'mentality_penalties', 'mentality_composure']

# %%
selected_features_with_target = df[selected_features['Feature'].values].copy()
selected_features_with_target[target_variable] = df[target_variable]

correlation_with_target = selected_features_with_target.corr()[target_variable].drop(target_variable)

sorted_features = correlation_with_target.abs().sort_values(ascending=False).index

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation_with_target[sorted_features].index, y=correlation_with_target[sorted_features].values, palette="coolwarm_r")  # "_r" reverses the color order

plt.xlabel("Selected Features")
plt.ylabel("Correlation with Target Variable")
plt.title("Correlation between Selected Features and Target Variable")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
independent_variables = [
    'age', 'height_cm', 'dribbling', 'attacking_heading_accuracy', 'skill_dribbling',
    'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
    'movement_balance', 'power_stamina', 'power_strength', 'power_long_shots',
    'mentality_aggression', 'mentality_interceptions', 'mentality_penalties', 'mentality_composure'
]

target_variable = ["big_potential"]

X = df[independent_variables]
y = df[target_variable]

y = np.ravel(y)

classification_reports = []
kappa_scores = []
conf_matrices = []
balanced_accuracies = []  

all_y_true = []
all_y_pred = []

fixed_hyperparameters = {
    'n_estimators': 50,
    'max_depth': 100,
    'criterion': 'gini',
    'bootstrap': False
}

skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

for fold_num, (train_index, test_index) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_index], X.iloc[test_index]
    y_train, y_val = y[train_index], y[test_index]

    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    rf_model = RandomForestClassifier(random_state=42, **fixed_hyperparameters)

    rf_model.fit(X_train_resampled, y_train_resampled)

    y_val_pred = rf_model.predict(X_val)

    all_y_true.extend(y_val)
    all_y_pred.extend(y_val_pred)

    accuracy_fold = accuracy_score(y_val, y_val_pred)
    precision_fold, recall_fold, f1_fold, _ = precision_recall_fscore_support(y_val, y_val_pred, average='binary')
    kappa_fold = cohen_kappa_score(y_val, y_val_pred)
    balanced_accuracy_fold = balanced_accuracy_score(y_val, y_val_pred)  

    report_fold = classification_report(y_val, y_val_pred, digits=3)
    classification_reports.append(f"Fold {fold_num}:\n{report_fold}\n")
    kappa_scores.append(kappa_fold)
    balanced_accuracies.append(balanced_accuracy_fold)
    conf_matrices.append(confusion_matrix(y_val, y_val_pred))

print("Combined Classification Reports for All Folds:\n")
print("\n".join(classification_reports))

print("Cohen's Kappa Scores for Each Fold:\n", kappa_scores)

print("Balanced Accuracies for Each Fold:\n", balanced_accuracies)

final_conf_matrix = confusion_matrix(all_y_true, all_y_pred)
print("Confusion Matrix for Final Evaluation on Entire Dataset:\n", final_conf_matrix)

final_report = classification_report(all_y_true, all_y_pred, digits=3)
final_kappa = cohen_kappa_score(all_y_true, all_y_pred)
final_balanced_accuracy = balanced_accuracy_score(all_y_true, all_y_pred)
print("Final Classification Report on Entire Dataset:\n", final_report)
print("Cohen's Kappa for Final Evaluation on Entire Dataset:", final_kappa)
print("Balanced Accuracy for Final Evaluation on Entire Dataset:", final_balanced_accuracy)

print("Fixed Hyperparameters:", fixed_hyperparameters)
# Out:
# Combined Classification Reports for All Folds:
#
# Fold 1:
#               precision    recall  f1-score   support
#
#            0      0.948     0.971     0.959      1035
#            1      0.500     0.353     0.414        85
#
#     accuracy                          0.924      1120
#    macro avg      0.724     0.662     0.687      1120
# weighted avg      0.914     0.924     0.918      1120
#
#
# Fold 2:
#               precision    recall  f1-score   support
#
#            0      0.953     0.967     0.960      1035
#            1      0.514     0.424     0.465        85
#
#     accuracy                          0.926      1120
#    macro avg      0.734     0.695     0.712      1120
# weighted avg      0.920     0.926     0.923      1120
#
#
# Fold 3:
#               precision    recall  f1-score   support
#
#            0      0.960     0.976     0.968      1035
#            1      0.632     0.506     0.562        85
#
#     accuracy                          0.940      1120
#    macro avg      0.796     0.741     0.765      1120
# weighted avg      0.935     0.940     0.937      1120
#
#
# Fold 4:
#               precision    recall  f1-score   support
#
#            0      0.954     0.972     0.963      1034
#            1      0.561     0.435     0.490        85
#
#     accuracy                          0.931      1119
#    macro avg      0.758     0.704     0.727      1119
# weighted avg      0.925     0.931     0.927      1119
#
#
# Fold 5:
#               precision    recall  f1-score   support
#
#            0      0.947     0.977     0.962      1034
#            1      0.547     0.341     0.420        85
#
#     accuracy                          0.929      1119
#    macro avg      0.747     0.659     0.691      1119
# weighted avg      0.917     0.929     0.921      1119
#
#
# Fold 6:
#               precision    recall  f1-score   support
#
#            0      0.956     0.963     0.960      1034
#            1      0.506     0.459     0.481        85
#
#     accuracy                          0.925      1119
#    macro avg      0.731     0.711     0.721      1119
# weighted avg      0.922     0.925     0.923      1119
#
#
# Fold 7:
#               precision    recall  f1-score   support
#
#            0      0.951     0.960     0.956      1034
#            1      0.453     0.400     0.425        85
#
#     accuracy                          0.918      1119
#    macro avg      0.702     0.680     0.690      1119
# weighted avg      0.913     0.918     0.915      1119
#
#
# Fold 8:
#               precision    recall  f1-score   support
#
#            0      0.949     0.962     0.955      1034
#            1      0.443     0.365     0.400        85
#
#     accuracy                          0.917      1119
#    macro avg      0.696     0.663     0.678      1119
# weighted avg      0.910     0.917     0.913      1119
#
#
# Fold 9:
#               precision    recall  f1-score   support
#
#            0      0.955     0.965     0.960      1034
#            1      0.514     0.447     0.478        85
#
#     accuracy                          0.926      1119
#    macro avg      0.734     0.706     0.719      1119
# weighted avg      0.921     0.926     0.923      1119
#
#
# Fold 10:
#               precision    recall  f1-score   support
#
#            0      0.950     0.973     0.961      1034
#            1      0.533     0.376     0.441        85
#
#     accuracy                          0.928      1119
#    macro avg      0.742     0.675     0.701      1119
# weighted avg      0.918     0.928     0.922      1119
#
#
# Cohen's Kappa Scores for Each Fold:
#  [0.3745072273324572, 0.4251082251082251, 0.5304130162703379, 0.4537968544967005, 0.3843699282039996, 0.44112540728232696, 0.3809128630705395, 0.3558017889752082, 0.4382699995766325, 0.40390648120745776]
# Balanced Accuracies for Each Fold:
#  [0.6619778346121057, 0.6953395851094061, 0.7408638817845978, 0.703623847991808, 0.6589828194333827, 0.7110365229263852, 0.680174081237911, 0.6634941404027762, 0.7061212879736034, 0.6746956422801229]
# Confusion Matrix for Final Evaluation on Entire Dataset:
#  [[10019   324]
#  [  501   349]]
# Final Classification Report on Entire Dataset:
#                precision    recall  f1-score   support
#
#            0      0.952     0.969     0.960     10343
#            1      0.519     0.411     0.458       850
#
#     accuracy                          0.926     11193
#    macro avg      0.735     0.690     0.709     11193
# weighted avg      0.919     0.926     0.922     11193
#
# Cohen's Kappa for Final Evaluation on Entire Dataset: 0.4193348118534055
# Balanced Accuracy for Final Evaluation on Entire Dataset: 0.6896313505582065
# Fixed Hyperparameters: {'n_estimators': 50, 'max_depth': 100, 'criterion': 'gini', 'bootstrap': False}

# %%
conf_matrix = np.array([[10019      , 324],
                       [501       , 349]])

conf_df = pd.DataFrame(conf_matrix, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])

sns.set(font_scale=1.5)

plt.figure(figsize=(10, 8))

sns.heatmap(conf_df, annot=True, fmt="d", cmap="Blues", linewidths=.5, cbar_kws={'label': 'Count'})

plt.xlabel('Predicted', fontsize=16)
plt.ylabel('Actual', fontsize=16)
plt.title('Confusion Matrix SMOTE\'d and Tuned XGBoost', fontsize=18)

plt.show()
