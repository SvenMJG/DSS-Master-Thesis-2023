# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
    cohen_kappa_score,
    balanced_accuracy_score,
)
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
import numpy as np

# %%
df.head()
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21906 entries, 0 to 21905
# Data columns (total 59 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    21906 non-null  int64
#  1   fifa_version                 21906 non-null  int64
#  2   long_name                    21906 non-null  object
#  3   player_positions             21906 non-null  object
#  4   overall                      21906 non-null  int64
#  5   potential                    21906 non-null  int64
#  6   age                          21906 non-null  int64
#  7   height_cm                    21906 non-null  int64
#  8   weight_kg                    21906 non-null  int64
#  9   nationality_id               21906 non-null  int64
#  10  nationality_name             21906 non-null  object
#  11  weak_foot                    21906 non-null  int64
#  12  skill_moves                  21906 non-null  int64
#  13  pace                         21906 non-null  float64
#  14  shooting                     21906 non-null  float64
#  15  passing                      21906 non-null  float64
#  16  dribbling                    21906 non-null  float64
#  17  defending                    21906 non-null  float64
#  18  physic                       21906 non-null  float64
#  19  attacking_crossing           21906 non-null  int64
#  20  attacking_finishing          21906 non-null  int64
#  21  attacking_heading_accuracy   21906 non-null  int64
#  22  attacking_short_passing      21906 non-null  int64
#  23  attacking_volleys            21906 non-null  int64
#  24  skill_dribbling              21906 non-null  int64
#  25  skill_curve                  21906 non-null  int64
#  26  skill_fk_accuracy            21906 non-null  int64
#  27  skill_long_passing           21906 non-null  int64
#  28  skill_ball_control           21906 non-null  int64
#  29  movement_acceleration        21906 non-null  int64
#  30  movement_sprint_speed        21906 non-null  int64
#  31  movement_agility             21906 non-null  int64
#  32  movement_reactions           21906 non-null  int64
#  33  movement_balance             21906 non-null  int64
#  34  power_shot_power             21906 non-null  int64
#  35  power_jumping                21906 non-null  int64
#  36  power_stamina                21906 non-null  int64
#  37  power_strength               21906 non-null  int64
#  38  power_long_shots             21906 non-null  int64
#  39  mentality_aggression         21906 non-null  int64
#  40  mentality_interceptions      21906 non-null  int64
#  41  mentality_positioning        21906 non-null  int64
#  42  mentality_vision             21906 non-null  int64
#  43  mentality_penalties          21906 non-null  int64
#  44  mentality_composure          21906 non-null  float64
#  45  defending_marking_awareness  21906 non-null  int64
#  46  defending_standing_tackle    21906 non-null  int64
#  47  defending_sliding_tackle     21906 non-null  int64
#  48  concatenated                 21906 non-null  object
#  49  preferred_foot_Left          21906 non-null  int64
#  50  preferred_foot_Right         21906 non-null  int64
#  51  Attacker                     21906 non-null  int64
#  52  Midfielder                   21906 non-null  int64
#  53  Defender                     21906 non-null  int64
#  54  Keeper                       21906 non-null  int64
#  55  improvement_1_year           21906 non-null  int64
#  56  improvement_2_years          21906 non-null  int64
#  57  improvement_3_years          21906 non-null  int64
#  58  big_potential                21906 non-null  int64
# dtypes: float64(7), int64(48), object(4)
# memory usage: 9.9+ MB
# Index(['player_id', 'fifa_version', 'long_name', 'player_positions', 'overall',
#        'potential', 'age', 'height_cm', 'weight_kg', 'nationality_id',
#        'nationality_name', 'weak_foot', 'skill_moves', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle', 'concatenated',
#        'preferred_foot_Left', 'preferred_foot_Right', 'Attacker', 'Midfielder',
#        'Defender', 'Keeper', 'improvement_1_year', 'improvement_2_years',
#        'improvement_3_years', 'big_potential'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import pandas as pd

independent_variables = ['age', 'height_cm', 'weight_kg', 'weak_foot', 'skill_moves', 'pace', 'shooting',
       'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'preferred_foot_Left', 'preferred_foot_Right', 'Attacker', 'Midfielder',
       'Defender', 'Keeper']

target_variable = "big_potential"
X = df[independent_variables]
y = df[target_variable]

clf = RandomForestClassifier()
clf.fit(X, y)

feature_importance = clf.feature_importances_

threshold = 0.025 

feature_importance_df = pd.DataFrame({'Feature': independent_variables, 'Importance': feature_importance})

selected_features = feature_importance_df[feature_importance_df['Importance'] > threshold]

print(selected_features)
print(selected_features['Feature'].tolist())
# Out:
#                        Feature  Importance
# 0                          age    0.064421
# 11          attacking_crossing    0.026777
# 12         attacking_finishing    0.025207
# 13  attacking_heading_accuracy    0.025220
# 14     attacking_short_passing    0.027161
# 15           attacking_volleys    0.027926
# 16             skill_dribbling    0.028083
# 17                 skill_curve    0.025051
# 18           skill_fk_accuracy    0.026839
# 20          skill_ball_control    0.025214
# 27               power_jumping    0.025320
# 28               power_stamina    0.025203
# 29              power_strength    0.025637
# 30            power_long_shots    0.025011
# 35         mentality_penalties    0.026525
# 36         mentality_composure    0.029494
# ['age', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_ball_control', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_penalties', 'mentality_composure']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

selected_features_with_target = df[selected_features['Feature'].values].copy()
selected_features_with_target[target_variable] = df[target_variable]

correlation_with_target = selected_features_with_target.corr()[target_variable].drop(target_variable)

sorted_features = correlation_with_target.abs().sort_values(ascending=False).index

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation_with_target[sorted_features].index, y=correlation_with_target[sorted_features].values, palette="coolwarm_r")  # "_r" reverses the color order

plt.xlabel("Selected Features")
plt.ylabel("Correlation with Target Variable")
plt.title("Correlation between Selected Features and Target Variable")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_fscore_support, cohen_kappa_score, balanced_accuracy_score
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np

['age', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 
 'skill_curve', 'skill_fk_accuracy', 'skill_ball_control', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_penalties', 'mentality_composure']

target_variable = ["big_potential"]

X = df[independent_variables]
y = df[target_variable]

y = np.ravel(y)

classification_reports = []
kappa_scores = []
conf_matrices = []
balanced_accuracies = []  

all_y_true = []
all_y_pred = []

fixed_hyperparameters = {
    'n_estimators': 50,
    'max_depth': 100,
    'criterion': 'gini',
    'bootstrap': False
}

skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

for fold_num, (train_index, test_index) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_index], X.iloc[test_index]
    y_train, y_val = y[train_index], y[test_index]

    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    rf_model = RandomForestClassifier(random_state=42, **fixed_hyperparameters)

    rf_model.fit(X_train_resampled, y_train_resampled)

    y_val_pred = rf_model.predict(X_val)

    all_y_true.extend(y_val)
    all_y_pred.extend(y_val_pred)

    accuracy_fold = accuracy_score(y_val, y_val_pred)
    precision_fold, recall_fold, f1_fold, _ = precision_recall_fscore_support(y_val, y_val_pred, average='binary')
    kappa_fold = cohen_kappa_score(y_val, y_val_pred)
    balanced_accuracy_fold = balanced_accuracy_score(y_val, y_val_pred)  # Calculate balanced accuracy

    report_fold = classification_report(y_val, y_val_pred, digits=3)
    classification_reports.append(f"Fold {fold_num}:\n{report_fold}\n")
    kappa_scores.append(kappa_fold)
    balanced_accuracies.append(balanced_accuracy_fold)
    conf_matrices.append(confusion_matrix(y_val, y_val_pred))

print("Combined Classification Reports for All Folds:\n")
print("\n".join(classification_reports))

print("Cohen's Kappa Scores for Each Fold:\n", kappa_scores)

print("Balanced Accuracies for Each Fold:\n", balanced_accuracies)

final_conf_matrix = confusion_matrix(all_y_true, all_y_pred)
print("Confusion Matrix for Final Evaluation on Entire Dataset:\n", final_conf_matrix)

final_report = classification_report(all_y_true, all_y_pred, digits=3)
final_kappa = cohen_kappa_score(all_y_true, all_y_pred)
final_balanced_accuracy = balanced_accuracy_score(all_y_true, all_y_pred)
print("Final Classification Report on Entire Dataset:\n", final_report)
print("Cohen's Kappa for Final Evaluation on Entire Dataset:", final_kappa)
print("Balanced Accuracy for Final Evaluation on Entire Dataset:", final_balanced_accuracy)

print("Fixed Hyperparameters:", fixed_hyperparameters)
# Out:
# Combined Classification Reports for All Folds:
#
# Fold 1:
#               precision    recall  f1-score   support
#
#            0      0.956     0.980     0.968      2039
#            1      0.598     0.401     0.480       152
#
#     accuracy                          0.940      2191
#    macro avg      0.777     0.691     0.724      2191
# weighted avg      0.932     0.940     0.934      2191
#
#
# Fold 2:
#               precision    recall  f1-score   support
#
#            0      0.957     0.986     0.971      2039
#            1      0.681     0.408     0.510       152
#
#     accuracy                          0.946      2191
#    macro avg      0.819     0.697     0.741      2191
# weighted avg      0.938     0.946     0.939      2191
#
#
# Fold 3:
#               precision    recall  f1-score   support
#
#            0      0.952     0.982     0.967      2039
#            1      0.591     0.342     0.433       152
#
#     accuracy                          0.938      2191
#    macro avg      0.772     0.662     0.700      2191
# weighted avg      0.927     0.938     0.930      2191
#
#
# Fold 4:
#               precision    recall  f1-score   support
#
#            0      0.956     0.982     0.969      2039
#            1      0.615     0.388     0.476       152
#
#     accuracy                          0.941      2191
#    macro avg      0.785     0.685     0.722      2191
# weighted avg      0.932     0.941     0.934      2191
#
#
# Fold 5:
#               precision    recall  f1-score   support
#
#            0      0.956     0.984     0.970      2039
#            1      0.645     0.395     0.490       152
#
#     accuracy                          0.943      2191
#    macro avg      0.801     0.689     0.730      2191
# weighted avg      0.935     0.943     0.936      2191
#
#
# Fold 6:
#               precision    recall  f1-score   support
#
#            0      0.954     0.982     0.968      2039
#            1      0.602     0.368     0.457       152
#
#     accuracy                          0.939      2191
#    macro avg      0.778     0.675     0.712      2191
# weighted avg      0.930     0.939     0.932      2191
#
#
# Fold 7:
#               precision    recall  f1-score   support
#
#            0      0.956     0.981     0.969      2039
#            1      0.608     0.391     0.476       151
#
#     accuracy                          0.941      2190
#    macro avg      0.782     0.686     0.722      2190
# weighted avg      0.932     0.941     0.935      2190
#
#
# Fold 8:
#               precision    recall  f1-score   support
#
#            0      0.953     0.985     0.968      2039
#            1      0.622     0.338     0.438       151
#
#     accuracy                          0.940      2190
#    macro avg      0.787     0.661     0.703      2190
# weighted avg      0.930     0.940     0.932      2190
#
#
# Fold 9:
#               precision    recall  f1-score   support
#
#            0      0.958     0.989     0.973      2039
#            1      0.741     0.417     0.534       151
#
#     accuracy                          0.950      2190
#    macro avg      0.850     0.703     0.754      2190
# weighted avg      0.943     0.950     0.943      2190
#
#
# Fold 10:
#               precision    recall  f1-score   support
#
#            0      0.958     0.979     0.968      2038
#            1      0.602     0.428     0.500       152
#
#     accuracy                          0.941      2190
#    macro avg      0.780     0.703     0.734      2190
# weighted avg      0.933     0.941     0.936      2190
#
#
# Cohen's Kappa Scores for Each Fold:
#  [0.4496504321549136, 0.4834482089117561, 0.4029589972109128, 0.4460543307454141, 0.46143045643953173, 0.42696200565166176, 0.4459213819464177, 0.4090907218448382, 0.5095384490095078, 0.4694055553070626]
# Balanced Accuracies for Each Fold:
#  [0.6906039467231099, 0.6968360393381688, 0.662224774786402, 0.6850058723316383, 0.6892762189927983, 0.6751374512790067, 0.686045945129576, 0.6612724066140719, 0.7032144701499566, 0.7032662310831053]
# Confusion Matrix for Final Evaluation on Entire Dataset:
#  [[20042   347]
#  [  929   588]]
# Final Classification Report on Entire Dataset:
#                precision    recall  f1-score   support
#
#            0      0.956     0.983     0.969     20389
#            1      0.629     0.388     0.480      1517
#
#     accuracy                          0.942     21906
#    macro avg      0.792     0.685     0.724     21906
# weighted avg      0.933     0.942     0.935     21906
#
# Cohen's Kappa for Final Evaluation on Entire Dataset: 0.4505924340015459
# Balanced Accuracy for Final Evaluation on Entire Dataset: 0.6852940692457218
# Fixed Hyperparameters: {'n_estimators': 50, 'max_depth': 100, 'criterion': 'gini', 'bootstrap': False}

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

conf_matrix = np.array([[20042      , 347],
                       [929       , 588]])

conf_df = pd.DataFrame(conf_matrix, index=['Actual Negative', 'Actual Positive'], columns=['Predicted Negative', 'Predicted Positive'])

sns.set(font_scale=1.5)

plt.figure(figsize=(10, 8))

sns.heatmap(conf_df, annot=True, fmt="d", cmap="Blues", linewidths=.5, cbar_kws={'label': 'Count'})

plt.xlabel('Predicted', fontsize=16)
plt.ylabel('Actual', fontsize=16)
plt.title('Confusion Matrix SMOTE\'d and Tuned XGBoost', fontsize=18)

plt.show()
